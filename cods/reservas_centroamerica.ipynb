# %%
import pandas as pd

# %%
df = pd.read_csv("db/reservas en centroamerica.csv")

# %%
df
# Out:
#           _key  1|RIN del Banco Central/2018-Enero/valorCalculado  \
# 0  El Salvador                                            3441.87
# 1    Guatemala                                           11345.90
# 2     Honduras                                            4674.03
# 3    Nicaragua                                            2739.80
# 4   Costa Rica                                            7120.05
#
#   1|RIN del Banco Central/2018-Enero/Fictisio  \
# 0                                           N
# 1                                           N
# 2                                           N
# 3                                           N
# 4                                           N
#
#    1|RIN del Banco Central/2018-Febrero/valorCalculado  \
# 0                                            3370.66
# 1                                           11475.20
# 2                                            4764.17
# 3                                            2770.90
# ...
